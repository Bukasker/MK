# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# 1. Wczytanie danych z pliku CSV
folder_path = '/content/drive/MyDrive/Folder'
file_path = os.path.join(folder_path, '6.csv')

# Używamy modułu csv, aby bezpiecznie przeczytać zawartość wiersza
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    # Pobieramy pierwszy wiersz (zakładając, że dane są w jednym wierszu)
    row = next(reader)
    # Konwertujemy wszystkie elementy na liczby zmiennoprzecinkowe (float)
    data = [float(x) for x in row]

# 2. Wizualizacja danych
plt.figure(figsize=(15, 6))
plt.plot(data, color='blue', linewidth=0.5)

plt.title("Wizualizacja sygnału z pliku 6.csv")
plt.xlabel("Numer próbki")
plt.ylabel("Wartość")
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# 3. Podstawowe statystyki
print(f"Liczba wczytanych punktów: {len(data)}")
print(f"Wartość maksymalna: {max(data)}")
print(f"Wartość minimalna: {min(data)}")
# Out:
# Liczba wczytanych punktów: 10000
# Wartość maksymalna: 10.96165356480321
# Wartość minimalna: -5.78022298785294
